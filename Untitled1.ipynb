# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 85)

# %%
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1.0         I agree                   None of these  18-24 years old
# 2.0         I agree  I am a developer by profession  25-34 years old
# 3.0         I agree  I am a developer by profession  45-54 years old
# 4.0         I agree  I am a developer by profession  25-34 years old
# 6.0         I agree  I am a developer by profession  35-44 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1.0                         NaN                                   NaN
# 2.0         Employed, full-time                                Remote
# 3.0         Employed, full-time  Hybrid (some remote, some in-person)
# 4.0         Employed, full-time  Hybrid (some remote, some in-person)
# 6.0         Employed, full-time                                Remote
#
#                                              CodingActivities  \
# ResponseId
# ...

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df['TimeSearching']
# Out:
# 0                         NaN
# 1         15-30 minutes a day
# 2         30-60 minutes a day
# 3         15-30 minutes a day
# 4        60-120 minutes a day
#                  ...
# 89179                     NaN
# 89180                     NaN
# 89181                     NaN
# 89182                     NaN
# 89183    60-120 minutes a day
# Name: TimeSearching, Length: 89184, dtype: object

# %%
df['WorkExp']
# Out:
# 0         NaN
# 1        10.0
# 2        23.0
# 3         7.0
# 4         6.0
#          ...
# 89179     NaN
# 89180     NaN
# 89181     NaN
# 89182     NaN
# 89183    14.0
# Name: WorkExp, Length: 89184, dtype: float64

# %%
df['WorkExp'].value_counts()
# Out:
# WorkExp
# 5.0     3299
# 10.0    3019
# 2.0     2796
# 3.0     2781
# 4.0     2529
# 7.0     2422
# 6.0     2329
# 1.0     2271
# 8.0     2232
# 15.0    2001
# 12.0    1719
# 20.0    1608
# 9.0     1425
# 11.0    1321
# 25.0    1202
# 13.0    1174
# 16.0     875
# 17.0     856
# 14.0     853
# 18.0     774
# 23.0     728
# 30.0     624
# 22.0     538
# 24.0     410
# 19.0     379
# 21.0     374
# 26.0     332
# 27.0     295
# 35.0     292
# 28.0     268
# 0.0      261
# 40.0     177
# 33.0     168
# 32.0     162
# 31.0     131
# 29.0     128
# 36.0     125
# 34.0     106
# 37.0      94
# 38.0      86
# 50.0      77
# 41.0      67
# 45.0      53
# 39.0      45
# 42.0      44
# 43.0      43
# 44.0      27
# 46.0      26
# 47.0      17
# 48.0      12
# 49.0       4
# Name: count, dtype: int64

# %%
df.iloc[[0,1]]
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0         1.0  I agree                   None of these  18-24 years old
# 1         2.0  I agree  I am a developer by profession  25-34 years old
#
#             Employment RemoteWork  \
# 0                  NaN        NaN
# 1  Employed, full-time     Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1  Books / Physical media;Colleague;Friend or fam...
#
#                                      LearnCodeOnline  ...       Frequency_1  \
# 0                                                NaN  ...               NaN
# ...

# %%
df.loc[0,'Age']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.loc[0,'Age']
#
# NameError: name 'df' is not defined

# %%
df.loc[[1,2,3],'LanguageHaveWorkedWith']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.loc[[1,2,3],'LanguageHaveWorkedWith']
#
# NameError: name 'df' is not defined

# %%
df.loc[[0:7],'MainBranch']
# Out:
#   Cell In[21], line 1
#     df.loc[[0:7],'MainBranch']
#              ^
# SyntaxError: invalid syntax

# %%
df.loc[0:7,'MainBranch']
# Out:
# 0                     None of these
# 1    I am a developer by profession
# 2    I am a developer by profession
# 3    I am a developer by profession
# 4    I am a developer by profession
# 5    I am a developer by profession
# 6    I am a developer by profession
# 7    I am a developer by profession
# Name: MainBranch, dtype: object

# %%
df.loc[0:, 'Age']
# Out:
# 0           18-24 years old
# 1           25-34 years old
# 2           45-54 years old
# 3           25-34 years old
# 4           25-34 years old
#                 ...
# 89179       25-34 years old
# 89180       18-24 years old
# 89181     Prefer not to say
# 89182    Under 18 years old
# 89183       35-44 years old
# Name: Age, Length: 89184, dtype: object

# %%
df.loc[0:10, 'Country']
# Out:
# 0                                                   NaN
# 1                              United States of America
# 2                              United States of America
# 3                              United States of America
# 4                                           Philippines
# 5     United Kingdom of Great Britain and Northern I...
# 6                              United States of America
# 7                              United States of America
# 8                                               Finland
# 9                                                 India
# 10                             United States of America
# Name: Country, dtype: object

# %%
df.loc[11:20, 'Country']
# Out:
# 11                                            Australia
# 12                             United States of America
# 13                             United States of America
# 14                                          Netherlands
# 15                                              Germany
# 16                                               Sweden
# 17                                               France
# 18                                              Albania
# 19                                              Germany
# 20    United Kingdom of Great Britain and Northern I...
# Name: Country, dtype: object

# %%
df.loc[0:10, 'MainBranch':'TechList']
# Out:
#                                            MainBranch              Age  \
# 0                                       None of these  18-24 years old
# 1                      I am a developer by profession  25-34 years old
# 2                      I am a developer by profession  45-54 years old
# 3                      I am a developer by profession  25-34 years old
# 4                      I am a developer by profession  25-34 years old
# 5                      I am a developer by profession  35-44 years old
# 6                      I am a developer by profession  35-44 years old
# 7                      I am a developer by profession  25-34 years old
# 8   I am not primarily a developer, but I write co...  45-54 years old
# 9                      I am a developer by profession  25-34 years old
# 10                     I am a developer by profession  25-34 years old
#
#                                            Employment  \
# 0                                                 NaN
# ...

# %%
df.loc[0:10, 'MainBranch':'LearnCode']
# Out:
#                                            MainBranch              Age  \
# 0                                       None of these  18-24 years old
# 1                      I am a developer by profession  25-34 years old
# 2                      I am a developer by profession  45-54 years old
# 3                      I am a developer by profession  25-34 years old
# 4                      I am a developer by profession  25-34 years old
# 5                      I am a developer by profession  35-44 years old
# 6                      I am a developer by profession  35-44 years old
# 7                      I am a developer by profession  25-34 years old
# 8   I am not primarily a developer, but I write co...  45-54 years old
# 9                      I am a developer by profession  25-34 years old
# 10                     I am a developer by profession  25-34 years old
#
#                                            Employment  \
# 0                                                 NaN
# ...

# %%
df.loc[1]
# Out:
# Q120                                           I agree
# MainBranch                               None of these
# Age                                    18-24 years old
# Employment                                         NaN
# RemoteWork                                         NaN
# CodingActivities                                   NaN
# EdLevel                                            NaN
# LearnCode                                          NaN
# LearnCodeOnline                                    NaN
# LearnCodeCoursesCert                               NaN
# YearsCode                                          NaN
# YearsCodePro                                       NaN
# DevType                                            NaN
# OrgSize                                            NaN
# PurchaseInfluence                                  NaN
# TechList                                           NaN
# BuyNewTool                                         NaN
# ...

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# Q310                  QID310
# Q120                  QID312
# S1                      QID1
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# TechList              QID322
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# ...

# %%
schema_df['question']
# Out:
# 0     <div><span style="font-size:19px;"><strong>Hel...
# 1                                     Browser Meta Info
# 2     <div><span style="font-size:19px;"><strong>You...
# 3
# 4     <span style="font-size:22px; font-family: aria...
# 5     Which of the following options best describes ...
# 6                                   What is your age? *
# 7     Which of the following best describes your cur...
# 8     Which best describes your current work situation?
# 9     Which of the following best describes the code...
# 10    <span style="font-size:22px; font-family: aria...
# 11    Which of the following best describes the high...
# 12     How do you learn to code? Select all that apply.
# 13    What online resources do you use to learn to c...
# 14    What online courses or certifications do you u...
# 15    Including any education, how many years have y...
# 16    NOT including education, how many years have y...
# 17    Which of the following describes your current ...
# ...

# %%
schema_df.loc['question']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'question'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
schema_df['qname']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'qname'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
schema_df['qname']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'qname'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# Q310                  QID310
# Q120                  QID312
# S1                      QID1
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# TechList              QID322
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# ...

# %%
schema_df.loc['Age']
# Out:
# qid                        QID127
# question      What is your age? *
# force_resp                   True
# type                           MC
# selector                     MAVR
# Name: Age, dtype: object

# %%
schema_df.loc['S7']
# Out:
# qid                                                      QID131
# question      <span style="font-size:22px;"><strong>Final Qu...
# force_resp                                                False
# type                                                         DB
# selector                                                     TB
# Name: S7, dtype: object

# %%
schema_df.loc['S7','question']
# Out:
# '<span style="font-size:22px;"><strong>Final Questions</strong></span><div><br></div>'

# %%
schema_df.sort_index()
# Out:
#                          qid  \
# qname
# AIAcc                 QID324
# AIBen                 QID316
# AIDev                 QID328
# AINext                QID320
# AIOpen                QID321
# AISearch              QID327
# AISelect              QID314
# AISent                QID315
# AITool                QID319
# Age                   QID127
# BuyNewTool            QID279
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# ICorPM                QID287
# Industry              QID326
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                          qid  \
# qname
# YearsCodePro           QID34
# YearsCode              QID32
# WorkExp               QID288
# Webframe              QID264
# ToolsTech             QID275
# TimeSearching         QID291
# TimeAnswering         QID292
# TechList              QID322
# TBranch               QID299
# SurveyLength          QID132
# SurveyEase            QID133
# SOVisitFreq           QID100
# SOTeamsUsage          QID286
# SOPartFreq            QID102
# SOComm                QID106
# SOAccount             QID101
# SOAI                  QID325
# S7                    QID131
# S6                    QID295
# S5                    QID313
# S4                     QID91
# S3                     QID61
# S2                    QID190
# S1                      QID1
# S0                     QID16
# RemoteWork            QID308
# Q310                  QID310
# Q120                  QID312
# PurchaseInfluence     QID278
# ProfessionalTech      QID304
# ...

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                 QID324
# AIBen                 QID316
# AIDev                 QID328
# AINext                QID320
# AIOpen                QID321
# AISearch              QID327
# AISelect              QID314
# AISent                QID315
# AITool                QID319
# Age                   QID127
# BuyNewTool            QID279
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# ICorPM                QID287
# Industry              QID326
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# ...

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1.0         I agree                   None of these     18-24 years old
# 2.0         I agree  I am a developer by profession     25-34 years old
# 3.0         I agree  I am a developer by profession     45-54 years old
# 4.0         I agree  I am a developer by profession     25-34 years old
# 6.0         I agree  I am a developer by profession     35-44 years old
# ...             ...                             ...                 ...
# 55144.0     I agree     I code primarily as a hobby  Under 18 years old
# 55145.0     I agree           I am learning to code     25-34 years old
# 55146.0     I agree           I am learning to code     18-24 years old
# 55147.0     I agree  I am a developer by profession     25-34 years old
# 55148.0     I agree     I code primarily as a hobby  Under 18 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# ...

# %%
df['ConvertedCompYearly']
# Out:
# ResponseId
# 1.0             NaN
# 2.0        285000.0
# 3.0        250000.0
# 4.0        156000.0
# 6.0         96828.0
#              ...
# 55144.0         NaN
# 55145.0         NaN
# 55146.0         NaN
# 55147.0    137550.0
# 55148.0         NaN
# Name: ConvertedCompYearly, Length: 38172, dtype: float64

# %%
df.loc['ConvertedCompYearly']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:19, in pandas._libs.index.Float64Engine._check_type()
#
# KeyError: 'ConvertedCompYearly'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.loc['ConvertedCompYearly']
#
# ...

# %%
high = (df['ConvertedCompYearly']>50000)

# %%
high
# Out:
# ResponseId
# 1.0        False
# 2.0         True
# 3.0         True
# 4.0         True
# 6.0         True
#            ...
# 55144.0    False
# 55145.0    False
# 55146.0    False
# 55147.0     True
# 55148.0    False
# Name: ConvertedCompYearly, Length: 38172, dtype: bool

# %%
df['high']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'high'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.loc['high']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:19, in pandas._libs.index.Float64Engine._check_type()
#
# KeyError: 'high'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df.loc['high']
#
# ...

# %%
df.loc[high]
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 2.0         I agree  I am a developer by profession  25-34 years old
# 3.0         I agree  I am a developer by profession  45-54 years old
# 4.0         I agree  I am a developer by profession  25-34 years old
# 6.0         I agree  I am a developer by profession  35-44 years old
# 7.0         I agree  I am a developer by profession  35-44 years old
# ...             ...                             ...              ...
# 55115.0     I agree  I am a developer by profession  18-24 years old
# 55122.0     I agree  I am a developer by profession  25-34 years old
# 55126.0     I agree  I am a developer by profession  35-44 years old
# 55135.0     I agree  I am a developer by profession  18-24 years old
# 55147.0     I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.loc[high,['DevType','Country','Currency','LanguageHaveWorkedWith','DatabaseHaveWorkedWith','ConvertedCompYearly']]
# Out:
#                                          DevType  \
# ResponseId
# 2.0         Senior Executive (C-Suite, VP, etc.)
# 3.0                          Developer, back-end
# 4.0                         Developer, front-end
# 6.0                          Developer, back-end
# 7.0                        Developer, full-stack
# ...                                          ...
# 55115.0                    Developer, full-stack
# 55122.0                    Developer, full-stack
# 55126.0                    Developer, full-stack
# 55135.0                   Database administrator
# 55147.0                        DevOps specialist
#
#                                                       Country  \
# ResponseId
# 2.0                                  United States of America
# 3.0                                  United States of America
# 4.0                                  United States of America
# 6.0         United Kingdom of Great Britain and Northern I...
# ...

# %%
countries = ['United States','India','Canada','Germany' ]

# %%
fil = df['Country'].isin(countries)

# %%
df.loc[fil,'Country']
# Out:
# ResponseId
# 41.0        Canada
# 42.0       Germany
# 46.0        Canada
# 47.0         India
# 48.0         India
#             ...
# 55136.0      India
# 55138.0    Germany
# 55140.0    Germany
# 55146.0    Germany
# 55147.0     Canada
# Name: Country, Length: 7076, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1.0                                                      NaN
# 2.0                               HTML/CSS;JavaScript;Python
# 3.0                               Bash/Shell (all shells);Go
# 4.0        Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 6.0        Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
#                                  ...
# 55144.0                             HTML/CSS;Java;JavaScript
# 55145.0                             GDScript;HTML/CSS;Python
# 55146.0    Bash/Shell (all shells);C++;HTML/CSS;Java;Java...
# 55147.0                   Bash/Shell (all shells);C++;Python
# 55148.0            C++;HTML/CSS;JavaScript;Python;TypeScript
# Name: LanguageHaveWorkedWith, Length: 38172, dtype: object

# %%
filt = df['LanguagesWorkedWith'].str.contains('Python', na=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguagesWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1.0                                                      NaN
# 2.0                               HTML/CSS;JavaScript;Python
# 3.0                               Bash/Shell (all shells);Go
# 4.0        Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 6.0        Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
#                                  ...
# 55144.0                             HTML/CSS;Java;JavaScript
# 55145.0                             GDScript;HTML/CSS;Python
# 55146.0    Bash/Shell (all shells);C++;HTML/CSS;Java;Java...
# 55147.0                   Bash/Shell (all shells);C++;Python
# 55148.0            C++;HTML/CSS;JavaScript;Python;TypeScript
# Name: LanguageHaveWorkedWith, Length: 38172, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1.0         I agree                   None of these     18-24 years old
# 2.0         I agree  I am a developer by profession     25-34 years old
# 3.0         I agree  I am a developer by profession     45-54 years old
# 4.0         I agree  I am a developer by profession     25-34 years old
# 6.0         I agree  I am a developer by profession     35-44 years old
# ...             ...                             ...                 ...
# 55144.0     I agree     I code primarily as a hobby  Under 18 years old
# 55145.0     I agree           I am learning to code     25-34 years old
# 55146.0     I agree           I am learning to code     18-24 years old
# 55147.0     I agree  I am a developer by profession     25-34 years old
# 55148.0     I agree     I code primarily as a hobby  Under 18 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# ...

# %%
df['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1.0                                                      NaN
# 2.0                               HTML/CSS;JavaScript;Python
# 3.0                               Bash/Shell (all shells);Go
# 4.0        Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 6.0        Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
#                                  ...
# 55144.0                             HTML/CSS;Java;JavaScript
# 55145.0                             GDScript;HTML/CSS;Python
# 55146.0    Bash/Shell (all shells);C++;HTML/CSS;Java;Java...
# 55147.0                   Bash/Shell (all shells);C++;Python
# 55148.0            C++;HTML/CSS;JavaScript;Python;TypeScript
# Name: LanguageHaveWorkedWith, Length: 38172, dtype: object

# %%
fil = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df[fil]
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 2.0         I agree  I am a developer by profession     25-34 years old
# 8.0         I agree  I am a developer by profession     25-34 years old
# 39.0        I agree  I am a developer by profession     25-34 years old
# 40.0        I agree  I am a developer by profession     25-34 years old
# 41.0        I agree  I am a developer by profession     18-24 years old
# ...             ...                             ...                 ...
# 55140.0     I agree  I am a developer by profession     18-24 years old
# 55145.0     I agree           I am learning to code     25-34 years old
# 55146.0     I agree           I am learning to code     18-24 years old
# 55147.0     I agree  I am a developer by profession     25-34 years old
# 55148.0     I agree     I code primarily as a hobby  Under 18 years old
#
#                                         Employment  \
# ResponseId
# ...

# %%
df.loc[fil,'Age']
# Out:
# ResponseId
# 2.0           25-34 years old
# 8.0           25-34 years old
# 39.0          25-34 years old
# 40.0          25-34 years old
# 41.0          18-24 years old
#                   ...
# 55140.0       18-24 years old
# 55145.0       25-34 years old
# 55146.0       18-24 years old
# 55147.0       25-34 years old
# 55148.0    Under 18 years old
# Name: Age, Length: 17822, dtype: object

# %%
df.loc[fil,'LanguageHaveWorkedWith','Age']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df.loc[fil,'LanguageHaveWorkedWith','Age']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1333, in _LocIndexer._getitem_tuple(self, tup)
#    1330     return self._getitem_lowerdim(tup)
# ...

# %%
df.loc[fil,['LanguageHaveWorkedWith','Age']]
# Out:
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 2.0                                HTML/CSS;JavaScript;Python
# 8.0         Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 39.0        C#;Java;JavaScript;Kotlin;PowerShell;Python;Ty...
# 40.0                               HTML/CSS;JavaScript;Python
# 41.0                                             C;C++;Python
# ...                                                       ...
# 55140.0     Assembly;Bash/Shell (all shells);C;C++;HTML/CS...
# 55145.0                              GDScript;HTML/CSS;Python
# 55146.0     Bash/Shell (all shells);C++;HTML/CSS;Java;Java...
# 55147.0                    Bash/Shell (all shells);C++;Python
# 55148.0             C++;HTML/CSS;JavaScript;Python;TypeScript
#
#                            Age
# ResponseId
# 2.0            25-34 years old
# 8.0            25-34 years old
# 39.0           25-34 years old
# 40.0           25-34 years old
# 41.0           18-24 years old
# ...
